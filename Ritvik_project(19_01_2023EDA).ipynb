# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi-rsl/Project1/blob/main/Ritvik_project(19_01_2023EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_app = pd.read_csv('/content/drive/My Drive/Project_Module2/Play Store Data.csv')

# %%
df_rev = pd.read_csv('/content/drive/My Drive/Project_Module2/User Reviews.csv')

# %%
df_app.head(6)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
# 5               Art & Design    March 26, 2017                 1.0
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up

# %%
df_rev.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# handling Duplicates

# %%
df_app[df_app.duplicated()].any()
# Out:
# App               True
# Category          True
# Rating            True
# Reviews           True
# Size              True
# Installs          True
# Type              True
# Price             True
# Content Rating    True
# Genres            True
# Last Updated      True
# Current Ver       True
# Android Ver       True
# dtype: bool

# %% [markdown]
# Dropping the duplicates from App column

# %%
 df_app.drop_duplicates(subset="App", inplace=True)

# %%
df_app.shape
# Out:
# (9660, 13)

# %% [markdown]
# Quick Check for Outliers

# %% [markdown]
# On studying the dataset further, it was found that there was a data with some kind of weird anomaly. Let us find out the row in the data and purge it.

# %%
df_app["Rating"].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %% [markdown]
# We have an app rating of 19 which is out of range and needs to be dropped

# %%
df_app[df_app["Rating"]==19]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# As we can see that this entry of our dataset is having a Rating of 19.0 which is way higher than the maximum rating of 5.0. Also, The value in the Reviews column has an alphabet which makes it a lone entry to have so. Hence we are removing this particular row to make our analysis easier.

# %% [markdown]
# Drop the row that has incorrect values for our features

# %%
index_to_drop = 10472
df_app = df_app.drop(index=index_to_drop)

# %%
df_app[df_app["Rating"]==19]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# 4. Check and Convert the Following columns for EDA analysis

# %%
df_app["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %% [markdown]
# Remove '+' and ',' from 'Installs' to make it numeric

# %%
df_app["Installs"] = df_app["Installs"].apply(lambda x:x.replace("+"," ")if "+" in str(x)else x)

# %%
df_app["Installs"] = df_app["Installs"].apply(lambda x:x.replace(","," ")if "," in str(x)else x)

# %%
df_app["Installs"].unique()
# Out:
# array(['10 000 ', '500 000 ', '5 000 000 ', '50 000 000 ', '100 000 ',
#        '50 000 ', '1 000 000 ', '10 000 000 ', '5 000 ', '100 000 000 ',
#        '1 000 000 000 ', '1 000 ', '500 000 000 ', '50 ', '100 ', '500 ',
#        '10 ', '1 ', '5 ', '0 ', '0'], dtype=object)

# %%
df_app["Installs"]=df_app["Installs"].str.replace(' ',' ')

# %%
df_app["Installs"]=df_app["Installs"].apply(lambda x: int(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-43b4a1b75d6a> in <cell line: 1>()
# ----> 1 df_app["Installs"]=df_app["Installs"].apply(lambda x: int(x))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-20-43b4a1b75d6a> in <lambda>(x)
# ----> 1 df_app["Installs"]=df_app["Installs"].apply(lambda x: int(x))
#
# ValueError: invalid literal for int() with base 10: '10 000 '

# %% [markdown]
# Since we get error while converting the data type of Installs column to integer, we are trying to remove '' inside the column as below

# %%
df_app["Installs"] = df_app["Installs"].apply(lambda x: int(x.replace(' ', '')))

# %%
df_app["Installs"]=df_app["Installs"].apply(lambda x: int(x))

# %%
df_app.describe()
# Out:
#             Rating      Installs
# count  8196.000000  9.659000e+03
# mean      4.173243  7.777507e+06
# std       0.536625  5.375828e+07
# min       1.000000  0.000000e+00
# 25%       4.000000  1.000000e+03
# 50%       4.300000  1.000000e+05
# 75%       4.500000  1.000000e+06
# max       5.000000  1.000000e+09

# %% [markdown]
# Its understood that both Installs and ratings are now the numeric columns

# %% [markdown]
# Size

# %%
df_app["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %% [markdown]
# We need to remove 'M' and 'k' from the column and to convert them into bytes. Also we need to remove the term "Varies with device"

# %%
def convert_size(size):
  if isinstance(size,str):
    if 'M' in size:
      return float(size.replace('M'," "))*1024*1024
    elif 'k' in size:
      return float(size.replace('k',' '))*1024
    elif "Varies with device" in size:
      return np.nan
  return size

# %%
df_app["Size"] = df_app["Size"].apply(convert_size)

# %%
df_app.describe()
# Out:
#             Rating          Size      Installs
# count  8196.000000  8.432000e+03  9.659000e+03
# mean      4.173243  2.138560e+07  7.777507e+06
# std       0.536625  2.288821e+07  5.375828e+07
# min       1.000000  8.704000e+03  0.000000e+00
# 25%       4.000000  4.823450e+06  1.000000e+03
# 50%       4.300000  1.258291e+07  1.000000e+05
# 75%       4.500000  2.936013e+07  1.000000e+06
# max       5.000000  1.048576e+08  1.000000e+09

# %% [markdown]
# Price & Reviews

# %%
df_app["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
## Remove "$" from "Price" columns to make it numeric
df_app["Price"] = df_app["Price"].apply(lambda x: x.replace("$",' ')if "$" in str(x) else(x))

# %%
df_app["Price"].unique()
# Out:
# array(['0', ' 4.99', ' 3.99', ' 6.99', ' 1.49', ' 2.99', ' 7.99', ' 5.99',
#        ' 3.49', ' 1.99', ' 9.99', ' 7.49', ' 0.99', ' 9.00', ' 5.49',
#        ' 10.00', ' 24.99', ' 11.99', ' 79.99', ' 16.99', ' 14.99',
#        ' 1.00', ' 29.99', ' 12.99', ' 2.49', ' 10.99', ' 1.50', ' 19.99',
#        ' 15.99', ' 33.99', ' 74.99', ' 39.99', ' 3.95', ' 4.49', ' 1.70',
#        ' 8.99', ' 2.00', ' 3.88', ' 25.99', ' 399.99', ' 17.99',
#        ' 400.00', ' 3.02', ' 1.76', ' 4.84', ' 4.77', ' 1.61', ' 2.50',
#        ' 1.59', ' 6.49', ' 1.29', ' 5.00', ' 13.99', ' 299.99', ' 379.99',
#        ' 37.99', ' 18.99', ' 389.99', ' 19.90', ' 8.49', ' 1.75',
#        ' 14.00', ' 4.85', ' 46.99', ' 109.99', ' 154.99', ' 3.08',
#        ' 2.59', ' 4.80', ' 1.96', ' 19.40', ' 3.90', ' 4.59', ' 15.46',
#        ' 3.04', ' 4.29', ' 2.60', ' 3.28', ' 4.60', ' 28.99', ' 2.95',
#        ' 2.90', ' 1.97', ' 200.00', ' 89.99', ' 2.56', ' 30.99', ' 3.61',
#        ' 394.99', ' 1.26', ' 1.20', ' 1.04'], dtype=object)

# %%
df_app.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Converting price column to float datatype
df_app["Price"]=df_app["Price"].apply(lambda x:float(x))

# %%
df_app.describe()
# Out:
#             Rating          Size      Installs        Price
# count  8196.000000  8.432000e+03  9.659000e+03  9659.000000
# mean      4.173243  2.138560e+07  7.777507e+06     1.099299
# std       0.536625  2.288821e+07  5.375828e+07    16.852152
# min       1.000000  8.704000e+03  0.000000e+00     0.000000
# 25%       4.000000  4.823450e+06  1.000000e+03     0.000000
# 50%       4.300000  1.258291e+07  1.000000e+05     0.000000
# 75%       4.500000  2.936013e+07  1.000000e+06     0.000000
# max       5.000000  1.048576e+08  1.000000e+09   400.000000

# %%
#converting "Reviews" column to int datatype
df_app["Reviews"]=df_app["Reviews"].apply(lambda x: int(x))

# %%
df_app.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df_app.describe(include="all").T
# Out:
#                  count unique                                             top  \
# App               9659   9659  Photo Editor & Candy Camera & Grid & ScrapBook
# Category          9659     33                                          FAMILY
# Rating          8196.0    NaN                                             NaN
# Reviews         9659.0    NaN                                             NaN
# Size            8432.0    NaN                                             NaN
# Installs        9659.0    NaN                                             NaN
# Type              9658      2                                            Free
# Price           9659.0    NaN                                             NaN
# Content Rating    9659      6                                        Everyone
# Genres            9659    118                                           Tools
# Last Updated      9659   1377                                  August 3, 2018
# Current Ver       9651   2817                              Varies with device
# Android Ver       9657     33                                      4.1 and up
#
#                 freq             mean              std     min        25%  \
# App                1              NaN              NaN     NaN        NaN
# Category        1832              NaN              NaN     NaN        NaN
# Rating           NaN         4.173243         0.536625     1.0        4.0
# Reviews          NaN    216592.563826   1831319.566176     0.0       25.0
# Size             NaN  21385599.113472  22888209.718209  8704.0  4823449.6
# Installs         NaN    7777506.73227  53758278.683523     0.0     1000.0
# Type            8902              NaN              NaN     NaN        NaN
# Price            NaN         1.099299        16.852152     0.0        0.0
# Content Rating  7903              NaN              NaN     NaN        NaN
# Genres           826              NaN              NaN     NaN        NaN
# Last Updated     252              NaN              NaN     NaN        NaN
# Current Ver     1055              NaN              NaN     NaN        NaN
# Android Ver     2202              NaN              NaN     NaN        NaN
#
#                        50%         75%           max
# App                    NaN         NaN           NaN
# Category               NaN         NaN           NaN
# Rating                 4.3         4.5           5.0
# Reviews              967.0     29401.0    78158306.0
# Size            12582912.0  29360128.0   104857600.0
# Installs          100000.0   1000000.0  1000000000.0
# Type                   NaN         NaN           NaN
# Price                  0.0         0.0         400.0
# Content Rating         NaN         NaN           NaN
# Genres                 NaN         NaN           NaN
# Last Updated           NaN         NaN           NaN
# Current Ver            NaN         NaN           NaN
# Android Ver            NaN         NaN           NaN

# %%
df_app.describe().T
# Out:
#            count          mean           std     min        25%         50%  \
# Rating    8196.0  4.173243e+00  5.366247e-01     1.0        4.0         4.3
# Reviews   9659.0  2.165926e+05  1.831320e+06     0.0       25.0       967.0
# Size      8432.0  2.138560e+07  2.288821e+07  8704.0  4823449.6  12582912.0
# Installs  9659.0  7.777507e+06  5.375828e+07     0.0     1000.0    100000.0
# Price     9659.0  1.099299e+00  1.685215e+01     0.0        0.0         0.0
#
#                  75%           max
# Rating           4.5  5.000000e+00
# Reviews      29401.0  7.815831e+07
# Size      29360128.0  1.048576e+08
# Installs   1000000.0  1.000000e+09
# Price            0.0  4.000000e+02

# %% [markdown]
# Missing Values

# %%
df_app.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size              1227
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# For the 'Rating' column, you might consider filling missing values with the mean or median rating.

# %%
df_app['Rating'].fillna(df_app['Rating'].mean(), inplace=True)

# %% [markdown]
# For the 'Size' column, you could use imputation techniques. For example, you might fill missing values with the mean or median size, or use a forward or backward fill.

# %%
df_app['Size'].fillna(df_app['Size'].mean(), inplace=True)

# %% [markdown]
# If the 'Type' column has only one missing value, you might manually inspect the data and fill it with the most common type.

# %%
df_app['Type'].fillna(df_app['Type'].mode()[0], inplace=True)

# %% [markdown]
# For 'Current Ver' and 'Android Ver,' you could fill missing values with the most common version or use forward or backward fill.

# %%
df_app['Current Ver'].fillna(df_app['Current Ver'].mode()[0], inplace=True)
df_app['Android Ver'].fillna(df_app['Android Ver'].mode()[0], inplace=True)

# %% [markdown]
# **Exploratory Data Analysis (EDA)**

# %% [markdown]
# Plot a pairwise plot between all the quantitative variables to look for any evident patterns or relationships between the features

# %%
columns_of_interest = ['Rating', 'Size', 'Installs', 'Reviews']

# %%
subset_df = df_app[columns_of_interest]

# %%
subset_df = subset_df.dropna()

# %%
sns.pairplot(subset_df)
plt.show()

# %% [markdown]
# Is there any difference between the category column and genres?

# %%
df_app[["Category","Genres"]]
# Out:
#                   Category                     Genres
# 0           ART_AND_DESIGN               Art & Design
# 1           ART_AND_DESIGN  Art & Design;Pretend Play
# 2           ART_AND_DESIGN               Art & Design
# 3           ART_AND_DESIGN               Art & Design
# 4           ART_AND_DESIGN    Art & Design;Creativity
# ...                    ...                        ...
# 10836               FAMILY                  Education
# 10837               FAMILY                  Education
# 10838              MEDICAL                    Medical
# 10839  BOOKS_AND_REFERENCE          Books & Reference
# 10840            LIFESTYLE                  Lifestyle
#
# [9659 rows x 2 columns]

# %% [markdown]
# Yes, It looks like they are slightly different

# %% [markdown]
# 1.Does the size of the app affect the ratings and number of installs?
# Let's now examine app size, review and rating. For size, if the mobile app is too large, it may be difficult and/or expensive for users to download. Lengthy download times could turn users off before they even experience your mobile app. Plus, each user's device has a finite amount of disk space. For price, some users expect their apps to be free or inexpensive. These problems compound if the developing world is part of your target market; especially due to internet speeds, earning power and exchange rates.

# %% [markdown]
# Correlation Analysis:
#
# Calculate the correlation coefficients between the 'Size' column and both the 'Rating' and 'Installs' columns. This will give you a numerical indication of the strength and direction of the relationship.

# %%
correlation_rating = df_app['Size'].corr(df_app['Rating'])
correlation_installs = df_app['Size'].corr(df_app['Installs'])

print(f'Correlation with Rating: {correlation_rating}')
print(f'Correlation with Installs: {correlation_installs}')
# Out:
# Correlation with Rating: 0.056598072381137766
# Correlation with Installs: 0.057951381751676266

# %% [markdown]
# # The correlation coefficients you provided indicate a very weak positive correlation between the 'Size' of the app and both the 'Rating' and 'Installs':
#
# Correlation with Rating: 0.0566
#
# A correlation coefficient close to 0 suggests a very weak linear relationship between the size of the app and its rating. In this case, the positive sign indicates a positive correlation, but the strength is negligible.
# Correlation with Installs: 0.0579
#
# Similarly, the correlation with installs is also very weak and positive. This suggests a slight positive association between the size of the app and the number of installs, but again, the relationship is weak.
# In practical terms, these correlation coefficients suggest that there isn't a strong linear relationship between the size of the app and either its rating or the number of installs. However, it's essential to note that correlation does not imply causation. Other factors not considered in this analysis could influence app ratings and installs.
#
# Additionally, the relationship might be nonlinear, or there could be confounding variables that impact the results. Further exploration, including visualizations and possibly statistical modeling, may provide more insights into the complex relationship between app size, ratings, and installs.

# %% [markdown]
# Visualization:
#
# Create scatter plots to visualize the relationship between 'Size' and 'Rating' and between 'Size' and 'Installs'.

# %%
# Scatter plot for Size vs Rating
sns.scatterplot(x='Size', y='Rating', hue = 'Type', data=df_app)
plt.title('Size vs Rating')
plt.show()

# %%
# Scatter plot for Size vs Installs
sns.scatterplot(x='Size',y="Installs",hue="Type",data=df_app)
plt.title('Size vs Rating')
plt.show()

# %% [markdown]
# What are the different categories of Apps downloaded?

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Category', data=df_app)
plt.xticks(rotation=90)
plt.title('Number of Apps in Each Category')
plt.show()

# %% [markdown]
# Box Plots for Ratings by Category:
#
# Use box plots to compare the distribution of ratings for different app categories. This can help identify categories with higher or lower average ratings.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Category', y='Rating', data=df_app)
plt.xticks(rotation=90)
plt.title('Distribution of Ratings by Category')
plt.show()

# %%
app_counts= df_app["Type"].value_counts()
app_counts
# Out:
# Free    8903
# Paid     756
# Name: Type, dtype: int64

# %%
plt.pie(app_counts, labels = app_counts.index,autopct='%1.1f%%', startangle = 90)
plt.title("Distribution of Free and Paid apps in Playstore")
plt.show()

# %% [markdown]
# 1. which is the most Installed app in each category?

# %%
df_app.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_app["Installs"]
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 9659, dtype: int64

# %%
sorted_data = df_app.sort_values(by=['Category','Installs'],ascending =False)
sorted_data
# Out:
#                                                     App        Category  \
# 3626  The Weather Channel: Rain Forecast & Storm Alerts         WEATHER
# 3628  AccuWeather: Daily Forecast & Live Weather Rep...         WEATHER
# 3649   GO Weather - Widget, Theme, Wallpaper, Efficient         WEATHER
# 4725                 Weather & Clock Widget for Android         WEATHER
# 3630    Weather by WeatherBug: Forecast, Radar & Alerts         WEATHER
# ...                                                 ...             ...
# 4193                                          صور حرف H  ART_AND_DESIGN
# 4764     X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN
# 5258  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper  ART_AND_DESIGN
# 8888            Spring flowers theme couleurs d t space  ART_AND_DESIGN
# 8871                             Test Application DT 02  ART_AND_DESIGN
#
#         Rating  Reviews          Size  Installs  Type  Price Content Rating  \
# 3626  4.400000  1558437  2.138560e+07  50000000  Free   0.00       Everyone
# 3628  4.400000  2053404  2.138560e+07  50000000  Free   0.00       Everyone
# 3649  4.500000  1422858  2.138560e+07  50000000  Free   0.00       Everyone
# 4725  4.400000  2371543  1.153434e+07  50000000  Free   0.00       Everyone
# 3630  4.500000   981995  2.138560e+07  10000000  Free   0.00       Everyone
# ...        ...      ...           ...       ...   ...    ...            ...
# 4193  4.400000       13  4.718592e+06      1000  Free   0.00       Everyone
# 4764  4.700000      149  3.670016e+06      1000  Paid   1.99       Everyone
# 5258  4.000000       18  3.774874e+06      1000  Free   0.00       Everyone
# 8888  5.000000        1  3.040870e+06       100  Free   0.00       Everyone
# 8871  4.173243        0  1.258291e+06         0  Free   0.00       Everyone
#
#             Genres    Last Updated         Current Ver         Android Ver
# 3626       Weather  August 1, 2018  Varies with device  Varies with device
# 3628       Weather  August 6, 2018  Varies with device  Varies with device
# 3649       Weather  August 3, 2018  Varies with device  Varies with device
# 4725       Weather    June 4, 2018             5.9.4.0        4.0.3 and up
# 3630       Weather    June 7, 2018  Varies with device  Varies with device
# ...            ...             ...                 ...                 ...
# 4193  Art & Design  March 27, 2018                 2.0        4.0.3 and up
# 4764  Art & Design   July 30, 2018               1.2.2          4.1 and up
# 5258  Art & Design  March 22, 2018                 1.1          4.0 and up
# 8888  Art & Design  April 18, 2018               1.0.2          4.0 and up
# 8871  Art & Design  March 14, 2017                 4.0          4.2 and up
#
# [9659 rows x 13 columns]

# %%
top_apps = sorted_data.groupby('Category').head(1)

# %%
print(top_apps[["Category","App","Installs"]])
# Out:
#                  Category                                                App  \
# 3626              WEATHER  The Weather Channel: Rain Forecast & Storm Alerts
# 3665        VIDEO_PLAYERS                                            YouTube
# 3117     TRAVEL_AND_LOCAL                          Maps - Navigate & Explore
# 3234                TOOLS                                             Google
# 4054               SPORTS                                         3D Bowling
# 2544               SOCIAL                                           Facebook
# 2655             SHOPPING                           Wish - Shopping Made Fun
# 3454         PRODUCTIVITY                                       Google Drive
# 2808          PHOTOGRAPHY                                      Google Photos
# 3354      PERSONALIZATION                      ZEDGE™ Ringtones & Wallpapers
# 7229            PARENTING     Pregnancy Tracker & Countdown to Baby Due Date
# 3736   NEWS_AND_MAGAZINES                                        Google News
# 2310              MEDICAL                                     Blood Pressure
# 3820  MAPS_AND_NAVIGATION  Waze - GPS, Maps, Traffic Alerts & Live Naviga...
# 4587            LIFESTYLE                                             Tinder
# 1523   LIBRARIES_AND_DEMO                         Aviary Stickers: Free Pack
# 1446       HOUSE_AND_HOME  Zillow: Find Houses for Sale & Apartments for ...
# 5596   HEALTH_AND_FITNESS                                     Samsung Health
# 1654                 GAME                                     Subway Surfers
# 1176       FOOD_AND_DRINK                                         McDonald's
# 1083              FINANCE                                         Google Pay
# 3975               FAMILY                                            Hay Day
# 1005               EVENTS                         Ticketmaster Event Tickets
# 865         ENTERTAINMENT                                  Google Play Games
# 699             EDUCATION                     Duolingo: Learn Languages Free
# 482                DATING                     Zoosk Dating App: Meet Singles
# 335         COMMUNICATION           Messenger – Text and Video Chat for Free
# 297                COMICS                         LINE WEBTOON - Free Comics
# 194              BUSINESS             OfficeSuite : Free Office + PDF Editor
# 152   BOOKS_AND_REFERENCE                                  Google Play Books
# 117                BEAUTY                      Beauty Camera - Selfie Camera
# 72      AUTO_AND_VEHICLES      Android Auto - Maps, Media, Messaging & Voice
# 3          ART_AND_DESIGN                              Sketch - Draw & Paint
#
#         Installs
# 3626    50000000
# 3665  1000000000
# 3117  1000000000
# 3234  1000000000
# 4054   100000000
# 2544  1000000000
# 2655   100000000
# 3454  1000000000
# 2808  1000000000
# 3354   100000000
# 7229    10000000
# 3736  1000000000
# 2310     5000000
# 3820   100000000
# 4587   100000000
# 1523    10000000
# 1446    10000000
# 5596   500000000
# 1654  1000000000
# 1176    10000000
# 1083   100000000
# 3975   100000000
# 1005     5000000
# 865   1000000000
# 699    100000000
# 482     10000000
# 335   1000000000
# 297     10000000
# 194    100000000
# 152   1000000000
# 117     10000000
# 72      10000000
# 3       50000000

# %%
plt.figure(figsize=(10,6))
plt.bar(top_apps['Category'], top_apps["Installs"],color='skyblue')
plt.xlabel("App Category")
plt.ylabel("Number of Installs")
plt.title("Most Installed apps in each Category")
plt.xticks(rotation =90, ha='right')
plt.tight_layout()
plt.show()

# %%
sorted_data_asc = df_app.sort_values(by=['Category','Installs'],ascending =True)

# %%
Least_Installed_apps = sorted_data.groupby('Category').head(1)

# %%
plt.figure(figsize=(10,6))
plt.bar(Least_Installed_apps["Category"], Least_Installed_apps["Installs"], color='green')
plt.xlabel("App Category")
plt.ylabel("Number of Installs")
plt.title("least Installed apps in each Category")
plt.xticks(rotation =90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# How is the rating distribution?

# %%
sns.countplot(x="Rating",data=df_app)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Rating Distribution on Play Store app')
plt.xticks(rotation =90, ha='right')
plt.show()

# %% [markdown]
# 4.	Which is the highest rated app in each category?

# %%
# Sort the DataFrame by 'Rating' in descending order within each category
df_sorted_rating = df_app.sort_values(by=['Category', 'Rating'], ascending=[True, False])

# %%
# Keep only the top-rated app in each category
df_top_rated_apps_rating = df_sorted_rating.groupby('Category').head(1)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Rating', y='Category', hue='App', data=df_top_rated_apps_rating, dodge=False)
plt.xlabel('Rating')
plt.ylabel('Category')
plt.title('Highest Rated App in Each Category')
plt.legend(title='App', bbox_to_anchor=(1, 1), loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128293 (\N{FIRE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 5.	Which is the lowest rated app in each category?

# %%
# Sort the DataFrame by 'Rating' in ascending order within each category
df_sorted_low = df_app.sort_values(by=['Category', 'Rating'], ascending=[True, True])

# Keep only the lowest-rated app in each category
df_lowest_rated_apps = df_sorted_low.groupby('Category').head(1)

# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(x='Rating', y='Category', hue='App', data=df_lowest_rated_apps, dodge=False)
plt.xlabel('Rating')
plt.ylabel('Category')
plt.title('Lowest Rated App in Each Category')
plt.legend(title='App', bbox_to_anchor=(1, 1), loc='upper left')
plt.show()
